# %%
# -*- coding: utf-8 -*-
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(open('591.html'),'lxml',from_encoding='utf-8')
print(soup.prettify("utf-8"))
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0051)https://rent.591.com.tw/?kind=0&region=3&section=26 -->
# <html lang="zh-TW">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="zh-TW" http-equiv="content-language"/>
#   <meta content="數字科技股份有限公司" name="author"/>
#   <meta content="591.com.tw" name="copyright"/>
#   <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    【新北市出租】-591房屋交易網
#   </title>
#   <meta content="新北市出租,出租,591,出租,591出租" name="keywords"/>
#   <meta content="591出租頻道,為您提供新北市最豐富的資訊,還有整層住家,獨立套房,分租套房,雅房,其他出租資訊,讓您快速找到滿意的物件。找就上591！" name="description"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="index,follow,archive" name="googlebot"/>
#   <meta content="hEZ-1CusNSS7yOwwpax-fT1lpRNSdL8muaPV-Ek1eIc" name="google-site-verification"/>
#   <!-- Open Graph data -->
#   <meta content="【新北市出租】-591房屋交易網" property="og:title"/>
#   <meta content="company" property="og:type"/>
#   <meta content="https://rent.591.com.tw/" property="og:url"/>
#   <meta content="" property="og:image"/>
#   <meta content="730" property="og:image:width"/>
#   <meta content="460" property="og:image:height"/>
#   <meta content="591出租頻道,為您提供新北市最豐富的資訊,還有整層住家,獨立套房,分租套房,雅房,其他出租資訊,讓您快速找到滿意的物件。找就上591！" property="og:description"/>
#   <meta content="1720154344667186" property="fb:app_id"/>
#   <meta content="591房屋交易" property="og:site_name"/>
#   <link href="https://rent.591.com.tw/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="./【新北市出租】-591房屋交易網_files/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="./【新北市出租】-591房屋交易網_files/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <script async="" src="./【新北市出租】-591房屋交易網_files/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="./【新北市出租】-591房屋交易網_files/linkid.js" type="text/javascript">
#   </script>
#   <script async="" src="./【新北市出租】-591房屋交易網_files/analytics.js">
#   </script>
#   <script async="" src="./【新北市出租】-591房屋交易網_files/tw591.js">
#   </script>
#   <script async="" src="./【新北市出租】-591房屋交易網_files/gtm.js">
#   </script>
#   <script src="./【新北市出租】-591房屋交易網_files/jquery-1.9.1.min.js" type="text/javascript">
#   </script>
#   <script src="./【新北市出租】-591房屋交易網_files/sea.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    seajs.config({preload:["https://rent.591.com.tw/" + seajs_env_path + "widget/config.js?v=659475f118"]});
#     !function () {
#         var env = location.host.search('debug') > -1
#             ? '.debug'
#             : location.host.search('dev') > -1
#                 ? '.dev'
#                 : ''
#
#         // 静态域名替換
#         seajs.config({base: '//s' + env + '.591.com.tw/' + seajs_env_path})
#     }();
# 	seajs.use("btjs");
#   </script>
#   <!--[if lt IE 9]>
#   	<script src="//s.591.com.tw/lib/html5shiv.min.js"></script>
# <![endif]-->
#   <link href="./【新北市出租】-591房屋交易網_files/default.public.css" rel="stylesheet" type="text/css"/>
#   <link href="./【新北市出租】-591房屋交易網_files/business.public.css" rel="stylesheet" type="text/css"/>
#   <link href="./【新北市出租】-591房屋交易網_files/list.css" rel="stylesheet"/>
#   <link href="./【新北市出租】-591房屋交易網_files/listSmall.css" media="screen and (max-width: 1400px)" rel="stylesheet" type="text/css"/>
#   <style>
#    @media  screen and (max-width: 1400px) {
#             .union_responsive img{ width:100%; }
#         }
#   </style>
#   <!-- Google Tag Manager -->
#   <script>
#    /**
# 	 * update 2017/06/16 by <dzq@addcn.com> filter iframe stat
# 	 *
# 	 * @params  GTM_IS_IFRAME{Number} global variable be use to filter iframe stat, 0-stat, 1-not stat.
# 	 */
# 	try {
# 		window.GTM_IS_IFRAME = top.location.href === window.location.href ? 0 : 1
# 	} catch (e) {
# 		window.GTM_IS_IFRAME = 0
# 	}
#
# 	// export userId
# 	var GTM_USER_ID = '0'
#
# 	;(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-K5L9PD');
#
# 	// tw591
# 	if(!GTM_IS_IFRAME){
# 		var ENV = location.search.indexOf('tw591') > -1 ? 'dev.' : '';
# 		(function(i,s,o,g,r,a,m){i['TW591AnalyticsObject']=r;i[r]=i[r]||function(){
# 	    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	    })(window,document,'script','//s.'+ ENV +'591.com.tw/widget/plugin/tw591.js?v=8c4a3e4ad8','tw591');
# 	}
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- addcn-591-jkb -->
#   <link charset="utf-8" href="./【新北市出租】-591房屋交易網_files/areaBoxNew.css" rel="stylesheet"/>
#   <style>
#    #cVim-command-bar, #cVim-command-bar-mode, #cVim-command-bar-input, #cVim-command-bar-search-results,
# .cVim-completion-item, .cVim-completion-item .cVim-full, .cVim-completion-item .cVim-left,
# .cVim-completion-item .cVim-right {
#   font-family: Helvetica, Helvetica Neue, Neue, sans-serif, monospace, Arial;
#   font-size: 10pt !important;
#   -webkit-font-smoothing: antialiased !important;
# }
#
# #cVim-command-bar {
#   position: fixed;
#   z-index: 2147483646;
#   background-color: #1b1d1e;
#   color: #bbb;
#   display: none;
#   box-sizing: content-box;
#   box-shadow: 0 3px 3px rgba(0,0,0,0.4);
#   left: 0;
#   width: 100%;
#   height: 20px;
# }
#
# #cVim-command-bar-mode {
#   display: inline-block;
#   vertical-align: middle;
#   box-sizing: border-box;
#   padding-left: 2px;
#   height: 100%;
#   width: 10px;
#   padding-top: 2px;
#   color: #888;
# }
#
# #cVim-command-bar-input {
#   background-color: #1b1d1e;
#   color: #bbb;
#   height: 100%;
#   right: 0;
#   top: 0;
#   width: calc(100% - 10px);
#   position: absolute;
# }
#
# #cVim-command-bar-search-results {
#   position: fixed;
#   width: 100%;
#   overflow: hidden;
#   z-index: 2147483647;
#   left: 0;
#   box-shadow: 0 3px 3px rgba(0,0,0,0.4);
#   background-color: #1c1c1c;
# }
#
# .cVim-completion-item, .cVim-completion-item .cVim-full, .cVim-completion-item .cVim-left, .cVim-completion-item .cVim-right {
#   text-overflow: ellipsis;
#   padding: 1px;
#   display: inline-block;
#   box-sizing: border-box;
#   vertical-align: middle;
#   overflow: hidden;
#   white-space: nowrap;
# }
#
# .cVim-completion-item:nth-child(even) {
#   background-color: #1f1f1f;
# }
#
# .cVim-completion-item {
#   width: 100%; left: 0;
#   color: #bcbcbc;
# }
#
# .cVim-completion-item[active] {
#   width: 100%; left: 0;
#   color: #1b1d1e;
#   background-color: #f1f1f1;
# }
#
# .cVim-completion-item[active] span {
#   color: #1b1d1e;
# }
#
# .cVim-completion-item .cVim-left {
#   color: #fff;
#   width: 37%;
# }
#
# .cVim-completion-item .cVim-right {
#   font-style: italic;
#   color: #888;
#   width: 57%;
# }
#
#
# #cVim-link-container, .cVim-link-hint,
# #cVim-hud, #cVim-status-bar {
#   font-family: Helvetica, Helvetica Neue, Neue, sans-serif, monospace, Arial;
#   font-size: 10pt !important;
#   -webkit-font-smoothing: antialiased !important;
# }
#
# #cVim-link-container {
#   position: absolute;
#   pointer-events: none;
#   width: 100%; left: 0;
#   height: 100%; top: 0;
#   z-index: 2147483647;
# }
#
# .cVim-link-hint {
#   position: absolute;
#   color: #302505 !important;
#   background-color: #ffd76e !important;
#   border-radius: 2px !important;
#   padding: 2px !important;
#   font-size: 8pt !important;
#   font-weight: 500 !important;
#   text-transform: uppercase !important;
#   border: 1px solid #ad810c;
#   display: inline-block !important;
#   vertical-align: middle !important;
#   text-align: center !important;
#   box-shadow: 2px 2px 1px rgba(0,0,0,0.25) !important;
# }
#
# .cVim-link-hint_match {
#   color: #777;
#   text-transform: uppercase !important;
# }
#
#
# #cVim-hud {
#   background-color: rgba(28,28,28,0.9);
#   position: fixed !important;
#   transition: right 0.2s ease-out;
#   z-index: 24724289;
# }
#
# #cVim-hud span {
#   padding: 2px;
#   padding-left: 4px;
#   padding-right: 4px;
#   color: #8f8f8f;
#   font-size: 10pt;
# }
#
# #cVim-frames-outline {
#   position: fixed;
#   width: 100%;
#   height: 100%;
#   left: 0;
#   top: 0;
#   right: 0;
#   z-index: 9999999999;
#   box-sizing: border-box;
#   border: 3px solid yellow;
# }
#   </style>
#   <link charset="utf-8" href="./【新北市出租】-591房屋交易網_files/popbox.css" rel="stylesheet"/>
#   <link charset="utf-8" href="./【新北市出租】-591房屋交易網_files/fixedfloat.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    &lt;iframe src="https://www.googletagmanager.com/ns.html?id=GTM-K5L9PD"
# height="0" width="0" style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <nav class="nav-wrapper">
#    <div class="nav">
#     <div class="logo">
#      <a google-data-stat="頭部導航_logo_1" href="https://www.591.com.tw/">
#       <img height="32" src="./【新北市出租】-591房屋交易網_files/logo.png" width="131"/>
#      </a>
#     </div>
#     <div class="area" id="areaSelect">
#      <a google-data-stat="頭部導航_縣市切換_1" href="javascript:;">
#       <span class="areaTxt">
#        新北市
#       </span>
#       <i class="fa fa-caret-down">
#       </i>
#      </a>
#      <div class="areabox-wrapper null" id="areaBoxNew">
#       <div class="dropbox-arrow">
#       </div>
#       <dl class="clearfix">
#        <dt>
#         北部
#        </dt>
#        <dd>
#         <a class="active" data-id="1" href="javascript:;">
#          台北市
#         </a>
#         <a class="active" data-id="3" href="javascript:;">
#          新北市
#         </a>
#         <a class="active" data-id="6" href="javascript:;">
#          桃園市
#         </a>
#         <a class="undefined" data-id="4" href="javascript:;">
#          新竹市
#         </a>
#         <a class="undefined" data-id="5" href="javascript:;">
#          新竹縣
#         </a>
#         <a class="undefined" data-id="21" href="javascript:;">
#          宜蘭縣
#         </a>
#         <a class="undefined" data-id="2" href="javascript:;">
#          基隆市
#         </a>
#        </dd>
#       </dl>
#       <dl class="clearfix">
#        <dt>
#         中部
#        </dt>
#        <dd>
#         <a class="active" data-id="8" href="javascript:;">
#          台中市
#         </a>
#         <a class="undefined" data-id="10" href="javascript:;">
#          彰化縣
#         </a>
#         <a class="undefined" data-id="14" href="javascript:;">
#          雲林縣
#         </a>
#         <a class="undefined" data-id="7" href="javascript:;">
#          苗栗縣
#         </a>
#         <a class="undefined" data-id="11" href="javascript:;">
#          南投縣
#         </a>
#        </dd>
#       </dl>
#       <dl class="clearfix">
#        <dt>
#         南部
#        </dt>
#        <dd>
#         <a class="active" data-id="17" href="javascript:;">
#          高雄市
#         </a>
#         <a class="undefined" data-id="15" href="javascript:;">
#          台南市
#         </a>
#         <a class="undefined" data-id="12" href="javascript:;">
#          嘉義市
#         </a>
#         <a class="undefined" data-id="13" href="javascript:;">
#          嘉義縣
#         </a>
#         <a class="undefined" data-id="19" href="javascript:;">
#          屏東縣
#         </a>
#        </dd>
#       </dl>
#       <dl class="clearfix">
#        <dt>
#         東部
#        </dt>
#        <dd>
#         <a class="undefined" data-id="22" href="javascript:;">
#          台東縣
#         </a>
#         <a class="undefined" data-id="23" href="javascript:;">
#          花蓮縣
#         </a>
#         <a class="undefined" data-id="24" href="javascript:;">
#          澎湖縣
#         </a>
#         <a class="undefined" data-id="25" href="javascript:;">
#          金門縣
#         </a>
#         <a class="undefined" data-id="26" href="javascript:;">
#          連江縣
#         </a>
#        </dd>
#       </dl>
#      </div>
#     </div>
#     <div class="nav-list">
#      <ul class="clearfix">
#       <li class="">
#        <a class="gtm-flag" google-data-stat="頭部導航_新建案_新建案" href="https://newhouse.591.com.tw/">
#         新建案
#        </a>
#        <div class="sub-nav">
#         <section class="nav-category subnav-newBuild">
#          <div class="sub-nav-list nav-wide">
#           <dl>
#            <dt>
#             銷售中新建案
#            </dt>
#            <dd>
#             <a google-data-stat="頭部導航_新建案_所有新建案" href="https://newhouse.591.com.tw/housing-list.html">
#              所有新建案
#             </a>
#             <a google-data-stat="頭部導航_新建案_預售屋" href="https://newhouse.591.com.tw/housing-list.html?build_type=1">
#              預售屋
#             </a>
#             <a google-data-stat="頭部導航_新建案_最新公開銷售" href="https://newhouse.591.com.tw/housing-list.html?now=1">
#              最新公開銷售
#             </a>
#             <a google-data-stat="頭部導航_新建案_新成屋" href="https://newhouse.591.com.tw/housing-list.html?build_type=2">
#              新成屋
#             </a>
#             <a google-data-stat="頭部導航_新建案_捷運宅" href="https://newhouse.591.com.tw/housing-list.html?type=1">
#              捷運宅
#             </a>
#            </dd>
#           </dl>
#          </div>
#          <div class="sub-nav-list nav-narrow">
#           <dl>
#            <dt>
#             買房工具
#            </dt>
#            <dd>
#             <a class="newFeatures" google-data-stat="頭部導航_新建案_環景720專區" href="https://newhouse.591.com.tw/home/housing/vr">
#              環景720專區
#             </a>
#             <a google-data-stat="頭部導航_新建案_實價登錄查詢" href="https://price.591.com.tw/">
#              實價登錄查詢
#             </a>
#             <a google-data-stat="頭部導航_新建案_房貸利率一覽表" href="https://www.591.com.tw/housing-bankapr.html">
#              房貸利率一覽表
#             </a>
#             <a google-data-stat="頭部導航_新建案_房貸試算器" href="https://www.591.com.tw/housing-fdss.html">
#              房貸試算器
#             </a>
#            </dd>
#           </dl>
#          </div>
#          <div class="sub-nav-list nav
#             </a>
#            </dd>
#           </dl>
#          </div>
#         </section>
#        </div>
#       </li>
#       <li>
#        <a class="gtm-flag" google-data-stat="頭部導航_社區_社區" href="https://www.591.com.tw/newCommunity-list.html">
#         社區
#        </a>
#       </li>
#       <li>
#        <a class="gtm-flag" google-data-stat="頭部導航_裝潢_裝潢" href="https://www.100.com.tw/works.html?bid=16&amp;utm_source=591.com.tw&amp;utm_medium=referral&amp;utm_campaign=591nav_bar" target="_blank">
#         裝潢
#        </a>
#       </li>
#       <li>
#        <a class="gtm-flag" href="javascript:;">
#         更多
#        </a>
#        <div class="sub-nav">
#         <section class="nav-category subnav-more">
#          <div class="sub-nav-list nav-narrow">
#           <dl>
#            <dt>
#             房屋周邊服務
#            </dt>
#            <dd>
#             <a google-data-stat="頭部導航_更多_搬家" href="https://life.591.com.tw/">
#              搬家
#             </a>
#             <a google-data-stat="頭部導航_更多_二手家具" href="https://home.591.com.tw/">
#              二手家具
#             </a>
#             <a google-data-stat="頭部導航_更多_討論區" href="https://bbs.591.com.tw/">
#              討論區
#             </a>
#            </dd>
#           </dl>
#          </div>
#         </section>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <div class="login-status">
#      <ul>
#       <li class="nav-link">
#        <a class="gtm-flag" google-data-stat="頭部導航_登入_登入" href="https://www.591.com.tw/user-login.html" target="_blank">
#         登入
#        </a>
#        <em class="divide-line">
#        </em>
#        <a class="gtm-flag" google-data-stat="頭部導航_註冊_註冊" href="https://www.591.com.tw/index.php?module=user" target="_blank">
#         註冊
#        </a>
#        <div class="dropbox nav-publish login-notice">
#         <div class="dropbox-arrow">
#         </div>
#         <a class="login-close" google-data-stat="頭部導航_登錄提示_關閉提示" href="javascript:;">
#         </a>
#         <p>
#          親愛的會員，登入功能搬到這裡啦！
#         </p>
#         <a class="login-btn active mr15" google-data-stat="頭部導航_登錄提示_會員登入" href="https://www.591.com.tw/user-login.html" target="_blank">
#          會員登入
#         </a>
#         <a class="login-btn" google-data-stat="頭部導航_登錄提示_免費註冊" href="https://www.591.com.tw/index.php?module=user" target="_blank">
#          免費註冊
#         </a>
#        </div>
#       </li>
#       <li class="dropMenu">
#        <div class="dropbox undis nav-publish">
#         <div class="dropbox-arrow">
#         </div>
#         <ul>
#          <li>
#           <a google-data-stat="頭部導航_登錄后下拉_會員中心" href="https://www.591.com.tw/index.php?module=userCenter">
#            會員中心
#           </a>
#          </li>
#          <li>
#           <a google-data-stat="頭部導航_登錄后下拉_退出" href="https://www.591.com.tw/index.php?module=user&amp;action=logout">
#            退出
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <li class="dropMenu nav-small-post">
#        <a google-data-stat="頭部導航_我要刊登_我要刊登" href="https://www.591.com.tw/index.php?module=house&amp;action=postFirst">
#         我要刊登
#         <i class="fa fa-caret-down">
#         </i>
#        </a>
#        <div class="dropbox undis nav-publish">
#         <div class="dropbox-arrow">
#         </div>
#         <ul>
#          <li>
#           <a google-data-stat="頭部導航_我要刊登_我要刊登" href="https://www.591.com.tw/index.php?module=house&amp;action=postFirst&amp;type=rent" target="_blank">
#            刊登出租
#           </a>
#          </li>
#          <li>
#           <a google-data-stat="頭部導航_我要刊登_我要刊登" href="https://www.591.com.tw/index.php?module=house&amp;action=postFirst&amp;type=sale" target="_blank">
#            刊登出售
#           </a>
#          </li>
#          <li>
#           <a google-data-stat="頭部導航_我要刊登_我要刊登" href="https://www.591.com.tw/index.php?module=housing&amp;action=housing" target="_blank">
#            刊登建案
#           </a>
#          </li>
#          <li>
#           <a google-data-stat="頭部導航_我要刊登_我要刊登" href="https://www.591.com.tw/help-charges.html" target="_blank">
#            收費標準
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <li class
#           <a class="drop-btn" google-data-stat="頭部導航_幫助_查看更多幫助內容" href="https://help.591.com.tw/" target="_blank">
#            查看更多幫助內容
#           </a>
#          </dd>
#         </dl>
#        </div>
#       </li>
#       <li class="dropMenu nav-small-addcn">
#        <a class="addcn" google-data-stat="頭部導航_addcn_addcn" href="http://www.addcn.com/" target="_blank">
#         <i class="fa fa-caret-down">
#         </i>
#        </a>
#        <div class="dropbox nav-addcn">
#         <div class="dropbox-arrow">
#         </div>
#         <dl rel="external nofollow">
#          <dt>
#           <a google-data-stat="頭部導航_addcn_8591寶物交易" href="http://www.8591.com.tw/" target="_blank">
#            <em class="nav-icon-8591">
#            </em>
#            8591寶物交易
#           </a>
#          </dt>
#          <dd>
#           各種遊戲寶物、遊戲幣、點數卡、道具、及帳號等交易。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_591房屋交易(台灣)" href="http://www.591.com.tw/" target="_blank">
#            <em class="nav-icon-591">
#            </em>
#            591房屋交易(台灣)
#           </a>
#          </dt>
#          <dd>
#           租屋、售屋、店面、新建案、搬家、設計、居家/傢俱廣告刊登等服務。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_591房屋交易(香港)" href="http://www.591.com.hk/" target="_blank">
#            <em class="nav-icon-591">
#            </em>
#            591房屋交易(香港)
#           </a>
#          </dt>
#          <dd>
#           提供香港住宅、寫字樓、工廠大廈、商鋪、車位、土地租售廣告免費刊登，資訊搜尋服務。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_100裝潢網" href="https://www.100.com.tw/" target="_blank">
#            <em class="nav-icon-100">
#            </em>
#            100裝潢網
#           </a>
#          </dt>
#          <dd>
#           提供裝潢設計公司、室內設計作品、裝潢知識與攻略等信息查找服務。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_8891汽車交易" href="http://www.8891.com.tw/" target="_blank">
#            <em class="nav-icon-8891">
#            </em>
#            8891汽車交易
#           </a>
#          </dt>
#          <dd>
#           提供中古車買賣，中古車行搜尋，新車圖片、配備規格查詢等服務。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_8891新車" href="http://c.8891.com.tw/" target="_blank">
#            <em class="nav-icon-8891">
#            </em>
#            8891新車
#           </a>
#          </dt>
#          <dd>
#           提供最新上市汽車資料，新車售價，高清實拍圖，網友評價。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_101名品會" href="http://www.101vip.com.tw/" target="_blank">
#            <em class="nav-icon-101-vip">
#            </em>
#            101名品會
#           </a>
#          </dt>
#          <dd>
#           提供VIP會員限定，名品服飾折扣3折起獨享優惠。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_518人力銀行" href="http://www.518.com.tw/" target="_blank">
#            <em class="nav-icon-518">
#            </em>
#            518人力銀行
#           </a>
#          </dt>
#          <dd>
#           找工作、找人才、人力媒合、職場討論等服務。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_518外包網" href="http://case.518.com.tw/" target="_blank">
#            <em class="nav-icon-518-bag">
#            </em>
#            518外包網
#           </a>
#          </dt>
#          <dd>
#           外包委外發案、兼差接案等服務。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_518黃頁" href="http://yp.518.com.tw/" target="_blank">
#            <em class="nav-icon-518-page">
#            </em>
#            518黃頁
#           </a>
#          </dt>
#          <dd>
#           免費廣告刊登，找公司、找服務，我們幫您解決生活大小事。
#          </dd>
#          <dt>
#           <a google-data-stat="頭部導航_addcn_結婚吧" href="http://www.marry.com.tw/" target="_blank">
#            <em class="nav-icon-marry">
#            </em>
#            結婚吧
#           </a>
#          </dt>
#          <dd>
#           一站式婚禮服務平台，提供準 新人們所需的各項婚禮服務。
#          </dd>
#         </dl>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </nav>
#   <script>
#    seajs.use(["areaBoxNew","cookie"],function(){
#
#         $("#areaSelect").areabox({
#             callback:function(obj){
#
#                 $("#areaSelect").find(".areaTxt").html(obj.text());
#
#                 // 首頁後台統計
#                 if (/www(\.(dev|debug))?\.591\.com\.tw\/home$/.test(location.href)) {
#                     $.post('//' + location.hostname + '/home/data/regionClick?cr=' + $.cookie('urlJumpIp') + '&r=' + obj.data('id'))
#                 }
#
#                 // 設置新的cookie
#                 $.cookie('urlJumpIp',obj.attr("data-id"),{expires: 30,path: '/',domain:'591.com.tw'});
#
#                 // 頁面刷新
#                 window.location.reload();
#
#             }
#         });
#
#         // 導航子菜單顯示
#         $(".nav-list li").bind({
#             "mouseover" : function(){
#                 $(this).addClass("active").find(".sub-nav").show();
#             },
#             "mouseout" : function(){
#                 $(this).removeClass("active").find(".sub-nav").hide();
#             }
#         })
#
#         // 狀態區域下拉
#         $(".login-status .dropMenu").bind({
#             "mouseover" : function(){
#                 $(this).addClass("active").find(".dropbox").show();
#             },
#             "mouseout" : function(){
#                 $(this).removeClass("active").find(".dropbox").hide();
#             }
#         })
#
#         // 獲取登錄提示展示次數
#         var _val = $.cookie("loginNoticeNumber") ? $.cookie("loginNoticeNumber") : 0;
#
#         //登錄提示框是否展示，超過三次就不再展示
#         if(!$.cookie("loginNoticeStatus") && _val <3){
#             $(".login-notice").show();
#         }
#
#         // 點擊關閉時同時寫入登錄提示次數cookie和展示cookie
#         $(".login-close").on("click",function(){
#             $(".login-notice").hide();
#
#             // 控制是否展示
#             $.cookie("loginNoticeStatus",1,{expires: 1,path: '/',domain:'591.com.tw'})
#
#             // 打入展示次數
#             $.cookie("loginNoticeNumber",parseInt(_val) + 1,{expires: 365,path: '/',domain:'591.com.tw'})
#
#         })
#     })
#   </script>
#   <div id="container">
#    <section class="searchBox">
#     <div class="searchBoxInput form-inline">
#      <input autocomplete="off" class="searchInput form-control" data-text="請輸入關鍵字（社區、街道、商圈等...）" id="keywords" name="keywords" placeholder="請輸入關鍵字（社區、街道、商圈等...）" type="text" value=""/>
#      <i style="">
#       <ul id="localCookies" style="display: none;">
#       </ul>
#      </i>
#      <span aria-hidden="true" class="searchBtn" google-data-stat=" 新版出租  _列表_搜寻按钮">
#      </span>
#      <i aria-hidden="true" class="searchBtn">
#      </i>
#      <ul class="hotWords clearfix">
#       <li class="first">
#        <strong style="color: #2e3436 ">
#         商用地產：
#        </strong>
#       </li>
#       <li class="first" google-data-stat="新版出租_列表_引導店面">
#        <a href="https://business.591.com.tw/?type=1&amp;kind=5&amp;businessSort=1" target="_blank">
#         店面
#        </a>
#       </li>
#       <li class="first" google-data-stat="新版出租_列表_引導辦公">
#        <a href="https://business.591.com.tw/?type=1&amp;kind=6&amp;businessSort=1" target="_blank">
#         辦公
#        </a>
#       </li>
#       <li class="first" google-data-stat="新版出租_列表_引導住辦">
#        <a href="https://business.591.com.tw/?type=1&amp;kind=12&amp;businessSort=1" target="_blank">
#         住辦
#        </a>
#       </li>
#       <li class="first" google-data-stat="新版出租_列表_引導廠房">
#        <a href="https://business.591.com.tw/?type=1&amp;kind=7&amp;businessSort=1" target="_blank">
#         廠房
#        </a>
#       </li>
#       <li class="first" google-data-stat="新版出租_列表_引導土地">
#        <a href="https://business.591.com.tw/?type=1&amp;kind=11&amp;businessSort=1" target="_blank">
#         土地
#        </a>
#       </li>
#       <li class="first" google-data-stat="新版出租_列表_引導頂讓">
#        <a href="https://business.591.com.tw/?type=6&amp;businessSort=1" target="_blank">
#         頂讓
#        </a>
#       </li>
#      </ul>
#      <div class="aLink">
#       <span class="mapLink">
#        <a google-data-stat="新版出租_列表_地圖找房" href="https://rent.591.com.tw/map-index.html" target="_blank">
#         地圖找房
#        </a>
#       </span>
#       <span class="communityLink">
#        <a google-data-stat="新版出租_列表_社區找房" href="https://rent.591.com.tw/rentCommunity.html" target="_blank">
#         社區找房
#        </a>
#       </span>
#      </div>
#     </div>
#    </section>
#    <div id="header-dealer">
#     <div class="union_responsive" id="UNION_22">
#     </div>
#    </div>
#    <!--麵包屑-->
#    <section class="breadBox">
#     <div class="breadNav clearfix">
#      <div class="breadList" id="breadList">
#       <a google-data-stat="新版出租 _列表_591面包屑" href="https://www.591.com.tw/">
#        591
#       </a>
#       <i aria-hidden="true" class="fa fa-angle-right">
#       </i>
#       <a google-data-stat="新版出租 _列表_新版面包屑" href="https://rent.591.com.tw/">
#        出租
#       </a>
#      </div>
#      <div class="conditionShow clearfix">
#       <span class="xs" data-bind="26">
#        板橋區
#        <i aria-hidden="true" class="closetips">
#        </i>
#       </span>
#      </div>
#      <a class="pull-right" google-data-stat="新版出租 _列表_訂閱電子報" href="javascript:void (0)" id="epaper" target="_blank">
#       <i aria-hidden="true" class="fa fa-file-text-o">
#       </i>
#       訂閱電子報
#      </a>
#      <a class="pull-right" href="javascript:;">
#       <i aria-hidden="true" class="fa fa-trash-o">
#       </i>
#       清除全部
#      </a>
#     </div>
#    </section>
#    <!--條件篩選-->
#    <section class="conditionBox">
#     <section class="condition">
#      <!--位置-->
#      <!--位置-->
#      <div id="search-location">
#       <strong>
#        位置：
#       </strong>
#       <span class="search-location-span " data-ie="search-location-span" data-index="1" google-data-stat="新版出租_列表_按縣市選擇">
#        新北市
#        <i class="fa fa-angle-down">
#        </i>
#       </span>
#       <span class="search-location-span select" data-ie="search-location-span" data-index="2" google-data-stat="新版出租_列表_按鄉鎮選擇">
#        按鄉鎮選擇
#        <i class="fa fa-angle-up">
#        </i>
#       </span>
#       <span class="search-location-span " data-ie="search-location-span" data-index="3" google-data-stat="新版出租_列表_按捷運選擇">
#        按捷運選擇
#        <i class="fa fa-angle-down">
#        </i>
#       </span>
#       <span class="search-location-span " data-ie="search-location-span" data-index="4" google-data-stat="新版出租_列表_按學校選擇">
#        按學校選擇
#        <i class="fa fa-angle-down">
#        </i>
#       </span>
#       <span class="search-location-span " data-ie="search-location-span" data-index="5" google-data-stat="新版出租_列表_按商圈選擇">
#        按商圈選擇
#        <i class="fa fa-angle-down">
#        </i>
#       </span>
#      </div>
#      <!--县市 乡镇 捷运 学校 商圈-->
#      <ul class="clearfix" id="optionBox">
#       <li class="clearfix rion">
#        <label class="checkTips" for="checktips26">
#         <input class="ck" data-bind="26" id="checktips26" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          板橋區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips50">
#         <input class="ck" data-bind="50" id="checktips50" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          淡水區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips44">
#         <input class="ck" data-bind="44" id="checktips44" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          新莊區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips38">
#         <input class="ck" data-bind="38" id="checktips38" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          中和區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips43">
#         <input class="ck" data-bind="43" id="checktips43" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          三重區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips37">
#         <input class="ck" data-bind="37" id="checktips37" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          永和區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips34">
#         <input class="ck" data-bind="34" id="checktips34" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          新店區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips27">
#         <input class="ck" data-bind="27" id="checktips27" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          汐止區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips47">
#         <input class="ck" data-bind="47" id="checktips47" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          蘆洲區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips39">
#         <input class="ck" data-bind="39" id="checktips39" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          土城區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips46">
#         <input class="ck" data-bind="46" id="checktips46" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          林口區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips40">
#         <input class="ck" data-bind="40" id="checktips40" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          三峽區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips41">
#         <input class="ck" data-bind="41" id="checktips41" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          樹林區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips48">
#         <input class="ck" data-bind="48" id="checktips48" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          五股區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips45">
#         <input class="ck" data-bind="45" id="checktips45" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          泰山區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips42">
#         <input class="ck" data-bind="42" id="checktips42" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          鶯歌區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips49">
#         <input class="ck" data-bind="49" id="checktips49" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          八里區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips28">
#         <input class="ck" data-bind="28" id="checktips28" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          深坑區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips51">
#         <input class="ck" data-bind="51" id="checktips51" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          三芝區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips20">
#         <input class="ck" data-bind="20" id="checktips20" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          萬里區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips30">
#         <input class="ck" data-bind="30" id="checktips30" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          瑞芳區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion">
#        <label for="checktips21">
#         <input class="ck" data-bind="21" id="checktips21" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          金山區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion" style="display: none;">
#        <label for="checktips36">
#         <input class="ck" data-bind="36" id="checktips36" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          烏來區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion" style="display: none;">
#        <label for="checktips29">
#         <input class="ck" data-bind="29" id="checktips29" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          石碇區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion" style="display: none;">
#        <label for="checktips33">
#         <input class="ck" data-bind="33" id="checktips33" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          貢寮區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion" style="display: none;">
#        <label for="checktips32">
#         <input class="ck" data-bind="32" id="checktips32" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          雙溪區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion" style="display: none;">
#        <label for="checktips52">
#         <input class="ck" data-bind="52" id="checktips52" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          石門區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion" style="display: none;">
#        <label for="checktips35">
#         <input class="ck" data-bind="35" id="checktips35" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          坪林區
#         </span>
#        </label>
#       </li>
#       <li class="clearfix rion" style="display: none;">
#        <label for="checktips31">
#         <input class="ck" data-bind="31" id="checktips31" name="sectionCk" type="checkbox"/>
#         <span class="txt">
#          平溪區
#         </span>
#        </label>
#       </li>
#       <div class="moreContent" google-data-stat="新版出租_列表_鄉鎮更多">
#        <em>
#         更多
#        </em>
#        <i aria-hidden="true" class="fa fa-angle-down">
#        </i>
#       </div>
#      </ul>
#      <ul class="clearfix" id="optionBoxs">
#      </ul>
#      <!--类型-->
#      <div class="search-condition" id="search-kind">
#       <strong>
#        類型：
#       </strong>
#       <span class="search-rentType-span search-unlimit" data-ie="search-rentType-span" data-index="0" data-name="rentType" google-data-stat="新版出租_列表_不限">
#        不限
#       </span>
# ...
#         })
#
#         // 是否顯示側邊工具欄
#         function sideTool(){
#             var _width = $(window).width();
#
#             if(_width > 1300){
#                 $(".side_tool_wrap").show();
#             }else{
#                 $(".side_tool_wrap").hide();
#             }
#         }
#
#         $(window).resize(function(){
#             sideTool();
#         })
#     })
#   </script>
#   <div class="area-select-box hidden" id="area-select-box">
#    <div class="area-box">
#     <div class="area-box-header">
#      <div class="area-box-title">
#       選擇縣市
#      </div>
#      <a class="area-box-close" google-data-stat="首頁_縣市選擇_關閉" href="https://rent.591.com.tw/?kind=0&amp;region=3&amp;section=26#" id="area-box-close">
#      </a>
#     </div>
#     <div class="area-box-body" id="area-box-body">
#     </div>
#    </div>
#    <div class="mask" google-data-stat="首頁_縣市選擇_關閉">
#    </div>
#    <input id="area-select-region-id" type="hidden" value="0"/>
#   </div>
#   <script id="area-select-box-template" type="text/html">
#    <@ for( x in regions ) { @>
#         <dl class="clearfix">
#             <@ for( y in regions[x] ) { @>
#                 <@ if( regions[x][y].id == 0 ) { @>
#                     <dt class="pull-left"><@= regions[x][y].txt @></dt>
#                 <@ } else { @>
#                     <dd google-data-stat="首頁_縣市選擇_<@= regions[x][y].txt @>" data-id="<@= regions[x][y].id @>" class="pull-left <@= regions[x][y].id == activeRegionID ? 'area-select-active' : '' @> "><@= regions[x][y].txt @></dd>
#                 <@ } @>
#             <@ } @>
#         </dl>
#     <@ } @>
#   </script>
#   <script>
#    seajs.use('areaselectbox')
#   </script>
#   <style>
#    .area-select-box .area-box-body a{
#         color: #737373;
#     }
#     .area-select-box .area-box-body{
#         padding-left: 20px;
#     }
#     .area-select-box .area-box-body dl{
#         margin-top: 17px;
#     }
#     .area-select-box .area-box-body dt{
#         margin-right: 20px;
#     }
#     .area-select-box .area-box-body dd{
#         margin-right: 10px;
#         width: 50px;
#         height: 20px;
#         line-height: 20px;
#         font-size: 14px;
#         text-align: center;
#         cursor: pointer;
#         color: #737373;
#     }
#     .area-select-box .area-box-body dd:hover,
#     #area-select-box.area-select-box .area-select-active{
#         background-color: #ff8000;
#         color: white;
#         border-radius: 3px;
#     }
#     .area-select-box{
#         position: fixed;
#         top: 0;
#         right: 0;
#         bottom: 0;
#         left: 0;
#         z-index: 999998;
#     }
#     .area-select-box .area-box{
#         position: absolute;
#         top: 50%;
#         left: 50%;
#         z-index: 999999;
#
#         width: 496px;
#         height: 214px;
#         margin-left: -248px;
#         margin-top: -107px;
#         border-radius: 5px;
#
#         background-color: white;
#     }
#     .area-select-box .mask{
#         position: absolute;
#         top: 0;
#         right: 0;
#         bottom: 0;
#         left: 0;
#
#         background-color: rgba(0,0,0,.68);
#     }
#     .area-select-box .area-box-header{
#         height: 46px;
#         line-height: 46px;
#         background: #f7f7f7;
#         box-sizing: border-box;
#         padding: 0 20px;
#         border-radius: 5px;
#     }
#     .area-select-box .area-box-title{
#         font-size: 20px;
#         color: #333;
#         float: left;
#     }
#     .area-select-box .area-box-close{
#         float: right;
#         background: url( '/static/public/component/areaselectbox/close.png' ) no-repeat;
#         display: inline-block;
#         width: 20px;
#         height: 20px;
#         margin-top: 13px;
#     }
#   </style>
#   <script>
#    seajs.use("houseList");
#   </script>
#   <script src="./【新北市出租】-591房屋交易網_files/UNION-v1.js" type="text/javascript">
#   </script>
#   <script>
#    // 頂部橫幅
#             UNION_SHOW({pid: 22,kid: 25})
#
#             // 底部橫幅
#             UNION_SHOW({pid: 23,kid: 26})
#   </script>
#   <!--列表页模板引擎-->
#   <script id="detailList" type="text/html">
#    <@ for (i = 0; i< data.length; i ++) { @>
#         <@ if(i == 10) {@>
#             <div id="list-up"></div>
#         <@ } @>
#     <ul class="listInfo clearfix <@ if(data[i]['addition3']) { @> addition3 <@ } @>">
#         <li class="pull-left imageBox" value="<@=data[i]['addition2']@>">
#              <img src="https://www.591.com.tw/images/index/house/newVersion/newlazy.gif" data-original="<@=data[i]['filename']@>" width="210" height="158" class="boxImg lazy" data-bind="<@=data[i]['id']@>" data-img-length="<@=data[i]['photoNum']@>"  alt="<@=data[i]['photo_alt']@>" title="<@=data[i]['photo_alt']@>">
#
#                             <@ if( data[i]['addition2'] == '1'){ @>
#                 <span class="worry"></span>
#                 <@ } @>
#
#
#             <@ if( data[i]['photoNum'] > 0 ){ @>
#             <div class="imgSort">
#                 <@=data[i]['photoNum']@>
#             </div>
#             <@ } @>
#         </li>
#         <li class="pull-left infoContent
#
#         <@ if( data[i]['distance_info']){ @>
#             distance_info
#         <@ } @>
#
#         ">
#             <h3>
#
#                 <a href=" //rent.591.com.tw/rent-detail-<@=data[i]['id']@>.html<@=data[i]['c_stat']@>  " target="_blank">
#
#                     <@=data[i]['address_img'] @></a>
#
#                 <@ if( data[i]['addition4']) {@>
#                 <span class="labelOne">黄金曝光</span>
#                 <@ }else if( data[i]['isvip']){@>
#                 <span class="labelThree">VIP</span>
#                 <@ } @>
#             </h3>
#
#
#             <p class="lightBox">
#
#                                                             <@=data[i]['kind_name'] @>
#
#                         <@ if(data[i]['layout']){ @>
#                         <i>&nbsp;&nbsp;|&nbsp;&nbsp;</i><@=data[i]['layout'] @>
#                         <@ } @>
#
#                         <@ if(data[i]['area']){ @>
#                         <i>&nbsp;&nbsp;|&nbsp;&nbsp;</i><@=data[i]['area'] @>坪
#                         <@ } @>
#
#                         <@ if(data[i]['floorInfo']){ @>
#                         <i>&nbsp;&nbsp;|&nbsp;&nbsp;</i><@=data[i]['floorInfo'] @>
#                         <@ } @>
#                                                 </p>
#             <p class="lightBox">
#
#                 <@ if (data[i]['cases_name']){@>
#
#                     <@ if (data[i]['cases_id']){@>
#
#                         <a href="//www.591.com.tw/newCommunity-index.html?cid=<@=data[i]['cases_id']@>" target="_blank"><@=data[i]['cases_name']@></a>
#
#                     <@ }else{ @>
#
#                         <@=data[i]['cases_name']@>
#
#                     <@ } @>
#
#                 <@ } @>
#
#
#                 <em><@=data[i]['section_name']@>-<@=data[i]['street_name']@><@=data[i]['alley_name']@><@=data[i]['lane_name']@><@=data[i]['addr_number_name']@><@=data[i]['addr_fci']@></em></p>
#             <p>
#                 <@ if(data[i]['nick_name']){@>
#                 <em><@=data[i]['nick_name']@> </em>
#                 <@ } @>
#
#                 <@ if(data[i]['posttime']){@>
#                 &nbsp;/&nbsp;<em><@=data[i]['posttime']@>更新</em>
#                 <@ } @>
#
#                 <@ if(data[i]['onepxImg'] == 1){@>
#                 <img class="onepx" style="width:1px; height:1px;" src="//www.591.com.tw/index.php?module=api&action=houseExposure&houseId=<@=data[i]['post_id']@>&type=<@=data[i]['type']@>" />
#                 <@ } @>
#
#                 <@ if(data[i]['comment_total']){@>
#                 &nbsp;/&nbsp;<em><@=data[i]['comment_total']@>條問答</em>
#                 <@ } @>
#
#                 <@ if(data[i]['browsenum']){@>
#                 &nbsp;/&nbsp;<em><@=data[i]['browsenum']@>人瀏覽</em>
#
#                                     <b class="showyestoday"></b>
#                                 <@ } @>
#
#             </p>
#             <@==data[i]['distance_info']@>
#             <span class="shoucang"><a data-text="<@=data[i]['id'] @>" data-colle="0" data-bind="1" href="javascript:;" title="收藏" google-data-stat="新版出租_列表_收藏"></a></span>
#         </li>
#         <div class="price"><i><@=data[i]['price']@></i>
#             <@=data[i]['unit']@>
#         </div>
#
#
#         <@ if(data[i]['new_img']){ @>
#         <div class="newArticle"></div>
#         <@ } @>
#
#     </a>
#     </ul>
#     <@ } @>
#   </script>
#   <!--列表已成交模板引擎-->
#   <script id="completedTpl" type="text/html">
#    <ul class="completed">
#         <@ for (t = 0; t < data.length; t++) { @>
#         <li class="clearfix">
#             <div class="cplAddress"><a href=" //rent.591.com.tw/rent-detail-<@=data[t]['post_id']@>.html  " target="_blank"><@=data[t]['region_name']@>-<@=data[t]['section_name']@>&nbsp;&nbsp;&nbsp;&nbsp;<@=data[t]['address']@></a></div>
#             <div class="cplDay"><@=data[t]['addInfo']@></div>
#             <div class="cplMuch"><@=data[t]['price']@><@=data[t]['unit']@></div>
#             <div class="cplSize"><@=data[t]['area']@>坪/<@=data[t]['kind_name']@></div>
#             <div class="cplTime"><@=data[t]['posttime']@></div>
#         </li>
#         <@ } @>
#     </ul>
#   </script>
#   <!--test-->
#   <!--位置-->
#   <script id="searchLocation" type="text/html">
#    <strong>位置：</strong>
#     <@ for (x in data) { @>
#         <span class="search-location-span <@ if(data[x] == '按鄉鎮選擇'){@>select<@ } @>" data-index="<@=x@>" google-data-stat=" 新版出租  _列表_<@=data[x]@>">
#         <@=data[x]@>&nbsp;&nbsp;
#         <@ if(data[x] == '按鄉鎮選擇'){@>
#             <i class="fa fa-angle-up" aria-hidden="true"></i>
#         <@ }else{ @>
#             <i class="fa fa-angle-down" aria-hidden="true"></i>
#         <@ } @>
#         </span>
#     <@ } @>
#   </script>
#   <!--//單選-->
#   <script id="singleSelect" type="text/html">
#    <strong><@=title@></strong>
#     <@ if (!!unlimit) { @>
#         <span class="search-<@=name@>-span search-unlimit" data-ie="search-<@=name@>-span" data-index="<@=unlimit@>" google-data-stat="新版出租_列表_不限" data-name="<@=name@>">
#         不限
#         </span>
#     <@ } @>
#     <@ for (x in data) { @>
#         <span class="search-<@=name@>-span" data-index="<@=x@>" data-ie="search-<@=name@>-span" google-data-stat="新版出租_列表_<@=data[x]@>" data-name="<@=name@>">
#         <@=data[x]@>
#         </span>
#     <@ } @>
#
#     <@ if (!!isInput) { @>
#         <sapn class="search-input-span">
#             <input type="text" class="<@=name@>-min  search-input-info" id="<@=name@>-min" data-name="<@=name@>">&nbsp;-&nbsp;
#             <input type="text" class="<@=name@>-max  search-input-info" id="<@=name@>-max" data-name="<@=name@>">&nbsp;元&nbsp;&nbsp;
#             <input class="search-input-btn <@=name@>-btn" data-ie="search-input-btn" type="button" value="確定" google-data-stat="新版出租_列表_自定义金额" data-name="<@=name@>">
#         </sapn>
#     <@ } @>
#
#     <@ if (!!isMore) { @>
#         <span class="search-change-more" data-ie="search-change-more" data-name="<@=moreName@>">多選</span>
#     <@ } @>
#   </script>
#   <!--//多選-->
#   <script id="moreSelect" type="text/html">
#    <strong><@=title@></strong>
#     <@ if (!!unlimit) { @>
#         <span class="search-<@=name@>-span search-unlimit-more" data-ie="search-unlimit-more" data-index="<@=unlimit@>" data-name="<@=name@>"  google-data-stat="新版出租_列表_不限">
#         不限
#         </span>
#     <@ } @>
#     <@ for (x in data) { @>
#         <label data-index="<@=x@>" data-name="<@=name@>"><input class="search-<@=singleName@>-more"  data-ie="search-<@=singleName@>-more" type="checkbox" value="1" data-name="<@=name@>" data-index="<@=x@>" google-data-stat="新版出租_列表_多選<@=data[x]@>"><@=data[x]@></label>
#     <@ } @>
#
#     <span class="search-change-single" data-ie="search-change-single" data-name="<@=singleName@>">單選</span>
#   </script>
#   <!--下拉多選-->
#   <script id="dropDown" type="text/html">
#    <button type="button" class="btn btn-default dropdown-toggle btn-sm" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#         <@=title@> <span class="caret"></span>
#     </button>
#     <ul class="dropdown-menu shapeList">
#     <@ if (!!unlimit) { @>
#         <li data-index="<@=unlimit@>" data-name="<@=name@>"><a href="javascript:;" google-data-stat=" 新版出租  _列表_房屋类型不限"><label><input class="search-dropdown-<@=name@>" type="checkbox" value="1" data-index="<@=x@>"  data-name="<@=name@>" id="<@=title@>-0"> <em>不限</em></label></a></li>
#
#     <@ } @>
#     <@ for (x in data) { @>
#         <li><a href="javascript:;" google-data-stat=" 新版出租  _列表_<@=title@><@=data[x]@>"><label data-index="<@=x@>"  data-name="<@=name@>"><input class="search-dropdown-<@=name@>" type="checkbox" value="1" data-index="<@=x@>" id="<@=title@>-<@=x@>" data-name="<@=name@>"> <em><@=data[x]@></em></label></a></li>
#
#      <@ } @>
#     </ul>
#   </script>
#   <!--下拉單選-->
#   <script id="dropDownOne" type="text/html">
#    <button type="button" class="btn btn-default dropdown-toggle btn-sm" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#         <@=title@> <span class="caret"></span>
#     </button>
#     <ul class="dropdown-menu <@=name@>List">
#     <@ if (!!unlimit) { @>
#         <li><a class="search-dropdown-<@=name@> search-unlimit" data-index="<@=unlimit@>"  data-name="<@=name@>" href="javascript:;" google-data-stat=" 新版出租  _列表_不限">不限</a></li>
#
#     <@ } @>
#     <@ for (x in data) { @>
#         <li><a class="search-dropdown-<@=name@>" data-index="<@=x@>"  data-name="<@=name@>" href="javascript:;" google-data-stat=" 新版出租  _列表_不限"><@=data[x]@></a></li>
#      <@ } @>
#     </ul>
#   </script>
#   <script>
#    //新版ga統計analytics.js
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         //增強的鏈接歸因
#         ga('require', 'linkid');
#
#         //主站 - 舊版統計合併
#         ga('create', 'UA-2021527-18', 'auto', {'name': 'tw591'});
#
#         //頁面統計
#         ga('tw591.send', 'pageview');
#
#         //再行銷
#         ga('require', 'displayfeatures');
#
#         //自定義ga插件
#         seajs.use("stat");
#   </script>
#   <script>
#    //設置賬號 - 新版出租
#     ga('create','UA-83787644-1','auto');
#     //頁面統計
#     ga('send', 'pageview');
#   </script>
#   <script type="text/javascript">
#    try{
#         top.location.hostname;
#         if (top.location.hostname != window.location.hostname) {
#             top.location.href =window.location.href;
#         }
#     }
#     catch(e){
#         top.location.href = window.location.href;
#     }
#   </script>
#   <script id="" type="text/javascript">
#    !function(c){function d(a){a=a.split("_");dataLayer.push({event:e,hot_event_1:a[0],hot_event_2:a[1],hot_event_3:a[2],hot_event_4:a[3]})}var f="data-gtm-stat",e="public_hot_event";c.addEventListener("click",function(a){for(var b=a.target;b!=c;b=b.parentNode||c)if(a=b.getAttribute(f)){d(a);break}});window.hotEventSend=d;Object.freeze(window.hotEventSend)}(document);
#   </script>
#   <div id="j_loading" rel="loading" style="position: absolute; z-index: 99992; left: 802.5px; top: 444.5px; display: none;">
#    <img height="100" src="./【新北市出租】-591房屋交易網_files/newLoading.gif" width="300"/>
#   </div>
#   <script id="" type="text/javascript">
#    !function(c,d,f){function g(){location.search.slice(1).split("\x26").forEach(function(b){b=b.split("\x3d");a[b[0]]=b[1]});a.school||a.busness||a.mrtline||(b.event="pc-rent-view-search",b.region=a.region||c.cookie("urlJumpIp"),b.section=a.section?-1<a.section.search(",")?"more":a.section:0,b.kind=a.kind?a.kind:0,b["rent-price"]=a.rentpriceMore?"more":a.rentprice?-1<a.rentprice.search(",")?"custom":"pc-rent-"+a.rentprice:0,"1"===a.kind&&(b.room=a.patternMore?"more":a.pattern?a.pattern:0),b.area=a.area?
# 0===c(".search-plain-span.select").length?"custom":"pc-rent-"+a.area:0,b.purpose=a.shape?-1<a.shape.search(",")?"more":a.shape:0,dataLayer.push(b),e=!0)}var a={},b={};f=c("#content");var e=!1,h=f.offset().top,k=c(d).height();c(".condition").click(function(){e=!1});c(d).scroll(function(){var a=c(d).scrollTop();a+k>h&&(e||g())})}(jQuery,window,document);
#   </script>
#  </body>
#  <div id="cVim-status-bar" style="top: 0px;">
#  </div>
#  <iframe id="cVim-command-frame" src="./【新北市出租】-591房屋交易網_files/cmdline_frame.html">
#  </iframe>
# </html>

# %%
content=soup.find('div',attrs={'id':'content'})

#print content.prettify("utf-8")
print len(content)
count =0
for each in content:
    if each.title == None:
        print "--------count %d--------"  %count
        print each
        print "---------------------"
        count=count+1
print count
# Out:
# 63
# --------count 0--------
# <ul class="listInfo clearfix ">
# <li class="pull-left imageBox" value="0">
# <img alt="新北租屋,板橋租屋,獨立套房出租,無印風格--時尚套房-府中站(仲介勿擾)" class="boxImg lazy" data-bind="5703672" data-img-length="6" data-original="https://hp1.591.com.tw/house/active/2017/10/17/150820516602813300_210x158.crop.jpg" height="158" src="./【新北市出租】-591房屋交易網_files/150820516602813300_210x158.crop.jpg" style="display: inline;" title="新北租屋,板橋租屋,獨立套房出租,無印風格--時尚套房-府中站(仲介勿擾)" visit-stated="" width="210"/>
# <div class="imgSort">
#                 6
#             </div>
# </li>
# <li class="pull-left infoContent ">
# <h3>
# <a href="https://rent.591.com.tw/rent-detail-5703672.html" target="_blank">
#
#                     無印風格--時尚套房-府中站(仲介勿擾)</a>
# <span class="labelOne">黄金曝光</span>
# </h3>
# <p class="lightBox">
#
#                                                             獨立套房
#
#
#
#
#                         <i>  |  </i>7坪
#
#
#
#                         <i>  |  </i>樓層：3/5
#
#                                                 </p>
# <p class="lightBox">
# <em>板橋區-成都街91巷</em></p>
# <p>
# <em>屋主 莊小姐 </em>
#
#
#
#                  / <em>5分鐘內更新</em>
#
#
#
#
#
#
#
#                  / <em>69人瀏覽</em>
# <b class="showyestoday"></b>
# </p>
# <span class="shoucang"><a data-bind="1" data-colle="0" data-text="5703672" google-data-stat="新版出租_列表_收藏" href="javascript:;" title="收藏"></a></span>
# </li>
# <div class="price"><i>13,500</i>
#             元/月
#         </div>
# </ul>
# ---------------------
# --------count 1--------
# <ul class="listInfo clearfix ">
# <li class="pull-left imageBox" value="0">
# <img alt="新北租屋,板橋租屋,獨立套房出租,板南、致理、北市、新北、板橋、府中套房" class="boxImg lazy" data-bind="5670011" data-img-length="4" data-original="https://hp2.591.com.tw/house/active/2016/12/03/148073258764342504_210x158.crop.jpg" height="158" src="./【新北市出租】-591房屋交易網_files/148073258764342504_210x158.crop.jpg" style="display: inline;" title="新北租屋,板橋租屋,獨立套房出租,板南、致理、北市、新北、板橋、府中套房" visit-stated="" width="210"/>
# <div class="imgSort">
#                 4
#             </div>
# </li>
# <li class="pull-left infoContent ">
# <h3>
# <a href="https://rent.591.com.tw/rent-detail-5670011.html" target="_blank">
#
#                     板南、致理、北市、新北、板橋、府中套房</a>
# <span class="labelOne">黄金曝光</span>
# </h3>
# <p class="lightBox">
#
#                                                             獨立套房
#
#
#
#
#                         <i>  |  </i>6坪
#
#
#
#                         <i>  |  </i>樓層：3/4
#
#                                                 </p>
# <p class="lightBox">
# <a href="https://www.591.com.tw/newCommunity-index.html?cid=546302" target="_blank">是8-2號非82號</a>
# <em>板橋區-建國街1巷</em></p>
# <p>
# <em>屋主 曾先生 </em>
#
#
#
#                  / <em>15分鐘內更新</em>
#
#
#
#
#
#                  / <em>1條問答</em>
#
#
#
#                  / <em>171人瀏覽</em>
# <b class="showyestoday"></b>
# </p>
# <span class="shoucang"><a data-bind="1" data-colle="0" data-text="5670011" google-data-stat="新版出租_列表_收藏" href="javascript:;" title="收藏"></a></span>
# </li>
# <div class="price"><i>8,000</i>
#             元/月
#         </div>
# </ul>
# ---------------------
# --------count 2--------
# <ul class="listInfo clearfix ">
# <li class="pull-left imageBox" value="0">
# <img alt="新北租屋,板橋租屋,分租套房出租,近捷運套房，歡迎養貓咪女性" class="boxImg lazy" data-bind="5665655" data-img-length="7" data-original="https://hp2.591.com.tw/house/active/2016/01/18/145309180488202309_210x158.crop.jpg" height="158" src="./【新北市出租】-591房屋交易網_files/145309180488202309_210x158.crop.jpg" style="display: inline;" title="新北租屋,板橋租屋,分租套房出租,近捷運套房，歡迎養貓咪女性" visit-stated="" width="210"/>
# <div class="imgSort">
#                 7
#             </div>
# </li>
# <li class="pull-left infoContent ">
# <h3>
# <a href="https://rent.591.com.tw/rent-detail-5665655.html" target="_blank">
#
#                     近捷運套房，歡迎養貓咪女性</a>
# <span class="labelOne">黄金曝光</span>
# </h3>
# <p class="lightBox">
#
#                                                             分租套房
#
#
#
#
#                         <i>  |  </i>6坪
#
#
#
#                         <i>  |  </i>樓層：5/5
#
#                                                 </p>
# <p class="lightBox">
# <em>板橋區-四川路一段286巷</em></p>
# <p>
# <em>屋主 周先生 </em>
#
#
#
#                  / <em>15分鐘內更新</em>
#
#
#
#
#
#                  / <em>2條問答</em>
#
#
#
#                  / <em>87人瀏覽</em>
# <b class="showyestoday"></b>
# </p>
# <span class="shoucang"><a data-bind="1" data-colle="0" data-text="5665655" google-data-stat="新版出租_列表_收藏" href="javascript:;" title="收藏"></a></span>
# </li>
# <div class="price"><i>8,000</i>
#             元/月
#         </div>
# </ul>
# ---------------------
# --------count 3--------
# <ul class="listInfo clearfix ">
# <li class="pull-left imageBox" value="0">
# <img alt="新北租屋,板橋租屋,分租套房出租,板橋大仁街.全新裝潢.獨洗.台藝大致理" class="boxImg lazy" data-bind="5706593" data-img-length="9" data-original="https://hp2.591.com.tw/house/active/2017/10/21/150859984267842402_210x158.crop.jpg" height="158" src="./【新北市出租】-591房屋交易網_files/newlazy.gif" title="新北租屋,板橋租屋,分租套房出租,板橋大仁街.全新裝潢.獨洗.台藝大致理" width="210"/>
# <div class="imgSort">
#                 9
#             </div>
# </li>
# <li class="pull-left infoContent ">
# <h3>
# <a href="https://rent.591.com.tw/rent-detail-5706593.html" target="_blank">
#
#                     板橋大仁街.全新裝潢.獨洗.台藝大致理</a>
# <span class="labelOne">黄金曝光</span>
# </h3>
# <p class="lightBox">
#
#                                                             分租套房
#
#
#
#
#                         <i>  |  </i>6坪
#
#
#
#                         <i>  |  </i>樓層：5/5
#
#                                                 </p>
# <p class="lightBox">
# <em>板橋區-大仁街</em></p>
# <p>
# <em>屋主 廖先生 </em>
#
#
#
#                  / <em>15分鐘內更新</em>
#
#
#
#
#
#
#
#                  / <em>537人瀏覽</em>
# <b class="showyestoday"></b>
# </p>
# <span class="shoucang"><a data-bind="1" data-colle="0" data-text="5706593" google-data-stat="新版出租_列表_收藏" href="javascript:;" title="收藏"></a></span>
# </li>
# <div class="price"><i>9,000</i>
#             元/月
#         </div>
# </ul>
# ---------------------
# --------count 4--------
# <ul class="listInfo clearfix ">
# <li class="pull-left imageBox" value="0">
# <img alt="新北租屋,板橋租屋,獨立套房出租,【近府中捷運站】簡約時尚套房" class="boxImg lazy" data-bind="5699584" data-img-length="15" data-original="https://hp1.591.com.tw/house/active/2016/09/21/147442469210556902_210x158.crop.jpg" height="158" src="./【新北市出租】-591房屋交易網_files/newlazy.gif" title="新北租屋,板橋租屋,獨立套房出租,【近府中捷運站】簡約時尚套房" width="210"/>
# <div class="imgSort">
#                 15
#             </div>
# </li>
# <li class="pull-left infoContent ">
# <h3>
# <a href="https://rent.591.com.tw/rent-detail-5699584.html" target="_blank">
#
#                     【近府中捷運站】簡約時尚套房</a>
# <span class="labelOne">黄金曝光</span>
# </h3>
# <p class="lightBox">
#
#                                                             獨立套房
#
#
#
#
#                         <i>  |  </i>7.5坪
#
#
#
#                         <i>  |  </i>樓層：3/5
#
#                                                 </p>
# <p class="lightBox">
# <em>板橋區-中山路一段</em></p>
# <p>
# <em>代理人 顧先生 </em>
#
#
#
#                  / <em>15分鐘內更新</em>
#
#
#
#
#
#
#
#                  / <em>47人瀏覽</em>
# <b class="showyestoday"></b>
# </p>
# <span class="shoucang"><a data-bind="1" data-colle="0" data-text="5699584" google-data-stat="新版出租_列表_收藏" href="javascript:;" title="收藏"></a></span>
# </li>
# <div class="price"><i>13,000</i>
#             元/月
#         </div>
# </ul>
# ---------------------
# --------count 5--------
# <ul class="listInfo clearfix ">
# <li class="pull-left imageBox" value="0">
# <img alt="新北租屋,板橋租屋,分租套房出租,新板特區，三鐵共構，交通便利" class="boxImg lazy" data-bind="5701985" data-img-length="9" data-original="https://hp2.591.com.tw/house/active/2015/06/27/143533884606692301_210x158.crop.jpg" height="158" src="./【新北市出租】-591房屋交易網_files/newlazy.gif" title="新北租屋,板橋租屋,分租套房出租,新板特區，三鐵共構，交通便利" width="210"/>
# <div class="imgSort">
#                 9
#             </div>
# </li>
# <li class="pull-left infoContent ">
# <h3>
# <a href="https://rent.591.com.tw/rent-detail-5701985.html" target="_blank">
#
#                     新板特區，三鐵共構，交通便利</a>
# <span class="labelOne">黄金曝光</span>
# </h3>
# <p class="lightBox">
#
#                                                             分租套房
#
#
#
#
#                         <i>  |  </i>4坪
#
#
#
#                         <i>  |  </i>樓層：3/5
#
#                                                 </p>
# <p class="lightBox">
# <em>板橋區-中山路一段158巷11號</em></p>
# <p>
# <em>屋主 黃小姐 </em>
#
#
#
#                  / <em>15分鐘內更新</em>
#
#
#
#
#
#
#
#                  / <em
#
#
#
#
#
#
#
#                  / <em>35人瀏覽</em>
# <b class="showyestoday"></b>
# </p>
# <span class="shoucang"><a data-bind="1" data-colle="0" data-text="5722761" google-data-stat="新版出租_列表_收藏" href="javascript:;" title="收藏"></a></span>
# </li>
# <div class="price"><i>25,000</i>
#             元/月
#         </div>
# </ul>
# ---------------------
# 31

# %%
# %ls -al
# %pylab inline
import matplotlib.pyplot as plt # plt 用于显示图片
import matplotlib.image as mpimg # mpimg 用于读取图片
content=soup.find('div',attrs={'id':'content'})

#print content.prettify("utf-8")
print len(content)
count =0
for each in content:
    if each.title == None:
        print "--------count %d--------"  %count
        if each.em == None :
            continue
        print each.em.text
        print each.find('div',attrs={'class':'price'}).i.text
        print each.a
        print each.a.attrs['href']
        print each.img
        image_src= each.img.attrs['src'].replace(u'【新北市出租】-591房屋交易網_files',"591_files")
        print image_src
        image_inst= mpimg.imread(image_src)
        plt.imshow(image_inst) # 显示图片
        plt.show()
        #em=each.find_all("em")
        #print em[0]
        #print em[1]
        i=0
        for each2 in each.find_all("em"):
            print "%d ,%s" %(i,each2.text)
            i=i+1
        print "---------------------"
        count=count+1
print count
# Out:
# total 868
# drwxr-xr-x 5 housesu housesu   4096 Oct 29 13:06 ./
# drwxr-xr-x 4 housesu housesu   4096 Oct 29 00:38 ../
# -rw-r--r-- 1 housesu housesu   1012 Oct 29 10:11 591_db.py
# drwx------ 2 housesu housesu   4096 Oct 29 10:18 591_files/
# -rw-r--r-- 1 housesu housesu 227314 Oct 29 10:16 591.html
# -rw-r--r-- 1 housesu housesu  16384 Oct 29 10:36 .591.html.swp
# -rw-r--r-- 1 housesu housesu 421807 Oct 29 13:06 bs4.ipynb
# -rw-r--r-- 1 housesu housesu 173104 Oct 29 10:13 geckodriver.log
# drwxr-xr-x 2 housesu housesu   4096 Oct 29 11:35 .ipynb_checkpoints/
# drwxr-xr-x 2 housesu housesu   4096 Oct 29 09:58 scrawler/
# -rw-r--r-- 1 housesu housesu   2634 Oct 29 10:09 simple.py
# -rw-r--r-- 1 housesu housesu   1767 Oct 28 22:07 sl.py
# -rw-r--r-- 1 housesu housesu     84 Oct 29 10:20 .spyderproject
# -rw-r--r-- 1 housesu housesu     68 Oct 29 10:20 .spyderworkspace
# Populating the interactive namespace from numpy and matplotlib
# 63
# --------count 0--------
# 板橋區-成都街91巷
# 13,500
# <a href="https://rent.591.com.tw/rent-detail-5703672.html" target="_blank">
#
#                     無印風格--時尚套房-府中站(仲介勿擾)</a>
# https://rent.591.com.tw/rent-detail-5703672.html
# <img alt="新北租屋,板橋租屋,獨立套房出租,無印風格--時尚套房-府中站(仲介勿擾)" class="boxImg lazy" data-bind="5703672" data-img-length="6" data-original="https://hp1.591.com.tw/house/active/2017/10/17/150820516602813300_210x158.crop.jpg" height="158" src="./【新北市出租】-591房屋交易網_files/150820516602813300_210x158.crop.jpg" style="display: inline;" title="新北租屋,板橋租屋,獨立套房出租,無印風格--時尚套房-府中站(仲介勿擾)" visit-stated="" width="210"/>
# ./591_files/150820516602813300_210x158.crop.jpg
# 0 ,板橋區-成都街91巷
# 1 ,屋主 莊小姐
# 2 ,5分鐘內更新
# 3 ,69人瀏覽
# ---------------------
# --------count 1--------
# 板橋區-建國街1巷
# 8,000
# <a href="https://rent.591.com.tw/rent-detail-5670011.html" target="_blank">
#
#                     板南、致理、北市、新北、板橋、府中套房</a>
# https://rent.591.com.tw/rent-detail-5670011.html
# <img alt="新北租屋,板橋租屋,獨立套房出租